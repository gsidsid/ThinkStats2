# %%
from thinkstats2 import Pmf, Cdf

import thinkstats2
import thinkplot
import numpy as np
import scipy

# %%
array = np.asarray([1, 1, 2, 3, 4, 4, 6, 7, 8, 9])

# %%
array
# Out:
# array([1, 1, 2, 3, 4, 4, 6, 7, 8, 9])

# %%
scipy.stats.sem(array)
# Out:
# 0.9098229375970787

# %%
array.std()/((len(array))**(0.5))
# Out:
# 0.8631338250816034

# %%
m = array.mean()
sus = 0
for i in array:
    sus += (m - i)**(2)
    
sus**0.5/len(array)
# Out:
# 0.8631338250816034

# %%
array.std()
# Out:
# 2.7294688127912363

# %% [markdown]
# #
